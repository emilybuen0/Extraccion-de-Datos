# %%
import json
import glob
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("HongKong_China_Data.csv")
df
# Out:
#                source    host_id   host_name  host_since host_location  \
# 0         city scrape     304876     Brendan  30/11/2010     Hong Kong
# 1     previous scrape    1300549      Darren  17/10/2011     Hong Kong
# 2         city scrape    1370155     Chuster  04/11/2011     Hong Kong
# 3         city scrape    1435069    Shanshan  23/11/2011     Hong Kong
# 4         city scrape    1443229        Shan  26/11/2011     Hong Kong
# ...               ...        ...         ...         ...           ...
# 6713      city scrape    4209137      Cherry  21/11/2012     Hong Kong
# 6714      city scrape   57341318       Edwin  04/02/2016     Hong Kong
# 6715      city scrape  667730514  James John  19/12/2024           NaN
# 6716      city scrape  280827591       Iryna  31/07/2019           NaN
# 6717      city scrape  668016531          佩涛  20/12/2024           NaN
#
#       host_response_time host_response_rate host_acceptance_rate  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6718 entries, 0 to 6717
# Data columns (total 50 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   source                                        6718 non-null   object
#  1   host_id                                       6718 non-null   int64
#  2   host_name                                     6718 non-null   object
#  3   host_since                                    6718 non-null   object
#  4   host_location                                 4431 non-null   object
#  5   host_response_time                            6401 non-null   object
#  6   host_response_rate                            6401 non-null   object
#  7   host_acceptance_rate                          6475 non-null   object
#  8   host_is_superhost                             6641 non-null   object
# ...

# %% [markdown]
# **b) Host unidos después del 2020**

# %%
#Reemplacé la / por -
#Convertí de cadena a datetime
df['host_since'] = df['host_since'].str.replace('/','-')
df['host_since'] = pd.to_datetime(df['host_since'], format = "%d-%m-%Y",errors='coerce')
dsps = df[df['host_since'] > pd.Timestamp("2020-01-01")]
dsps
# Out:
#            source    host_id   host_name host_since host_location  \
# 2563  city scrape  515763765       Danny 2023-05-21           NaN
# 2564  city scrape  515763765       Danny 2023-05-21           NaN
# 2611  city scrape  326920595        Anna 2020-01-12           NaN
# 2617  city scrape  340318261   Airy Stay 2020-03-05           NaN
# 2619  city scrape  340318261   Airy Stay 2020-03-05           NaN
# ...           ...        ...         ...        ...           ...
# 6708  city scrape  489744412      Lailai 2022-11-30     Hong Kong
# 6709  city scrape  489744412      Lailai 2022-11-30     Hong Kong
# 6710  city scrape  489744412      Lailai 2022-11-30     Hong Kong
# 6715  city scrape  667730514  James John 2024-12-19           NaN
# 6717  city scrape  668016531          佩涛 2024-12-20           NaN
#
#      host_response_time host_response_rate host_acceptance_rate  \
# 2563                NaN                NaN                  NaN
# ...

# %%
dsps.to_csv("B")
